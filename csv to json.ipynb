# %%
import pandas as pd
import json

# %%
dataset = pd.read_csv("recap.csv", encoding= 'unicode_escape')
dataset
# Out:
#         drone_model dataset         controller  \
# 0     DJI_Inspire_1   df010         mobile_iOS
# 1     DJI_Inspire_1   df010         mobile_iOS
# 2     DJI_Inspire_1   df010         mobile_iOS
# 3     DJI_Inspire_1   df010         mobile_iOS
# 4     DJI_Inspire_1   df010         mobile_iOS
# ...             ...     ...                ...
# 1851      DJI_Spark   df008  mobile_iOS_backup
# 1852      DJI_Spark   df008  mobile_iOS_backup
# 1853      DJI_Spark   df008         mobile_iOS
# 1854      DJI_Spark   df008         mobile_iOS
# 1855      DJI_Spark   df008         mobile_iOS
#
#                                        source_file       date      time  \
# 0     336-80799827e1156d2c54438d9e04b6100afbaad8e3  6/29/2017  15:24:31
# 1     336-80799827e1156d2c54438d9e04b6100afbaad8e3  6/29/2017  15:24:31
# 2     336-80799827e1156d2c54438d9e04b6100afbaad8e3  6/29/2017  15:24:32
# 3     336-80799827e1156d2c54438d9e04b6100afbaad8e3  6/29/2017  15:24:32
# ...

# %%
dataset.to_json(r'dataset.json')
